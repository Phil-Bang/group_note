# %% [markdown]
# # 문제
#
# * 데이터이름: `young_survey.csv`
# * 일찍 일어나는 사람들이 좋아할 만한 음악이 무엇인지 분석해보라
# * 데이터 중 “Getting up”이라는 column을 보면 사람들이 아침에 일어나는 걸 얼마나 어려워하는지 알 수 있
#   - 5라고 대답한 사람들은 아침에 일어나는 걸 아주 어려워 하는 사람들
#   - 1이라고 대답한 사람들은 아침에 쉽게 일어나는 사람
#
# 이 데이터로 봤을 때, 아침에 일찍 일어나는 사람들이 가장 좋아할 만한 음악 장르는 무엇일까?
#
# 1. [] Rock n roll
# 1. [] Dance
# 1. [] Classical music
# 1. [X] Opera
# 1. [] Swing, Jazz

# %% [markdown]
# # 해결

# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("./data/young_survey.csv")

# %%
df.head()
# Out:
#    Music  Slow songs or fast songs  Dance  Folk  Country  Classical music  \
# 0    5.0                       3.0    2.0   1.0      2.0              2.0
# 1    4.0                       4.0    2.0   1.0      1.0              1.0
# 2    5.0                       5.0    2.0   2.0      3.0              4.0
# 3    5.0                       3.0    2.0   1.0      1.0              1.0
# 4    5.0                       3.0    4.0   3.0      2.0              4.0
#
#    Musical  Pop  Rock  Metal or Hardrock  ...  Spending on looks  \
# 0      1.0  5.0   5.0                1.0  ...                3.0
# 1      2.0  3.0   5.0                4.0  ...                2.0
# 2      5.0  3.0   5.0                3.0  ...                3.0
# 3      1.0  2.0   2.0                1.0  ...                4.0
# 4      3.0  5.0   3.0                1.0  ...                3.0
#
#    Spending on gadgets  Spending on healthy eating   Age  Height  Weight  \
# ...

# %%
df.corr()["Getting up"].sort_values(ascending=True)
# Out:
# Prioritising workload        -0.256098
# Finances                     -0.202493
# Workaholism                  -0.163420
# Healthy eating               -0.145313
# Reliability                  -0.139184
# Physics                      -0.138385
# Age                          -0.119888
# Happiness in life            -0.116574
# Chemistry                    -0.114936
# Active sport                 -0.110472
# Mathematics                  -0.109566
# Documentary                  -0.102092
# Thinking ahead               -0.096450
# Energy levels                -0.090133
# Spending on healthy eating   -0.084574
# Science and technology       -0.084106
# Keeping promises             -0.076505
# Gardening                    -0.075320
# Opera                        -0.071819
# Western                      -0.071302
# Biology                      -0.070370
# Action                       -0.067689
# Religion                     -0.066783
# Parents' advice              -0.062700
# ...
